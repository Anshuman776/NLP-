# %%
import re

# %%
mail ='anshuman2313043@akgec.ac.in'
p= '[A-za-z0-9]+@[\w]+.[\w]+.[\w]+'  
re.search(p,mail)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\v\AppData\Local\Temp\ipykernel_23584\4232254478.py:2: SyntaxWarning: invalid escape sequence '\w'
#   p= '[A-za-z0-9]+@[\w]+.[\w]+.[\w]+'
# <re.Match object; span=(0, 27), match='anshuman2313043@akgec.ac.in'>

# %%
re.search(p,'anshumanmaurya@akgec.ac.org').group()
# Out:
# 'anshumanmaurya@akgec.ac.org'

# %%
txt = 'Anshuman maurya454@akgec.ac.in to contact Anshuman Maurya'
print(re.findall(p,txt))
# Out:
# ['maurya454@akgec.ac.in']

# %% [markdown]
# # as you can see that it only  show the selected pattern match from whole game

# %% [markdown]
# # Email ID with Specific Domain

# %%
mail1 = 'Anshumanmaury11@akgec.ac.in'
mail2 = 'Anshumanmaurya23@gmail.com'
p = '[A-za-z0-9]+@(akgec).(ac).(in)$'
# her the $ sign idicate that after any thing present should not be written 
print(re.search(p,mail1))
print(re.search(p,mail2))
# Out:
# <re.Match object; span=(0, 27), match='Anshumanmaury11@akgec.ac.in'>
# None

# %%
print(re.search(p,'rajgupta@akgec.ac.indy'))
# Out:
# None

# %%
print(re.search(p,'rajgupta@akgec.ac.org'))
# Out:
# None

# %% [markdown]
# # Email Id with selected Domain

# %%
mail = 'anshuman2313043@akgec.ac.in'
p='[A-Za-z0-9]+@[A-Za-z]+.(ac|org|gov|net|in)+.(in|com|org)'
re.search(p,mail)
# Out:
# <re.Match object; span=(0, 27), match='anshuman2313043@akgec.ac.in'>

# %%
re.search(p,'anshumanmaurya@fhdb.gov.org')
# Out:
# <re.Match object; span=(0, 27), match='anshumanmaurya@fhdb.gov.org'>
