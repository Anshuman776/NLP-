# %%
print('hello' in 'hello world')
print('data' in 'hello DATA')
# Out:
# True
# False

# %%
import re 

print(re.search('hello','hello world'))
print(re.search('data','hello world'))
# Out:
# <re.Match object; span=(0, 5), match='hello'>
# None

# %%
# span shows index where it belong to

# %%
s=re.search('hello','hello world')
print(s.span())
print(s.start())
print(s.end())
# Out:
# (0, 5)
# 0
# 5

# %%
# to find the frequency of words present in the text we can see use the findall function 
a= "hello how are area are you ?"
b="are"
re.findall(b,a)
# Out:
# ['are', 'are', 'are']

# %%
# Now if we want to traverse through the whole text and find the span of the desired word present in the string we can use the finditer function
for i in re.finditer('hello','hello world hello earth hello universe'):
    print(i.span())
# Out:
# (0, 5)
# (12, 17)
# (24, 29)

# %% [markdown]
# # Creating Regular expression

# %%
txt1 = "my telephone number is 834-4324-345"
txt2= "my telephone number is 8344324325"
pattern = '\d{3}-\d{4}-\d{3}'
print(re.search(pattern,txt1))
print(re.search(pattern,txt2))
# Out:
# <re.Match object; span=(23, 35), match='834-4324-345'>
# None
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\v\AppData\Local\Temp\ipykernel_8092\4080773159.py:3: SyntaxWarning: invalid escape sequence '\d'
#   pattern = '\d{3}-\d{4}-\d{3}'

# %% [markdown]
# For txt1 we got the pattern matched as \d indicated digits and the number inside the parenthesis {} indicated the number of those digits which should be present in the txt
#
# For txt2 we got None because although the digits were present the ‘-‘ (hyphen) was not present between the digits so the pattern was not matched.

# %%
print(re.search(pattern,txt1).group())
# Out:
# 834-4324-345

# %% [markdown]
# if we want to display the specific number which we got by matching our pattern we can use the group function .
# if i use txt2 at this place it will not show me
