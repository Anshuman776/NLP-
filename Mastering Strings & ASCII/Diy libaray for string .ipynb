# %%
import nlp as nlp

# %%
result = nlp.capitalize('hello, how are you?')
print(result)
# Out:
# Hello, how are you?

# %%
result = nlp.check_digit('wer4')
print(result)
# Out:
# False

# %%
result = nlp.check_alnum('wer4')
print(result)
# Out:
# True

# %%
print(nlp.title('how are you'))
# Out:
# How Are You

# %% [markdown]
# # as in this mannner we can find out all values that we create by on in one libaray as nlp where we have stored all functions that we can dirctly call from our logic
