# %%
txt = "Hello everyone welcome to my space"
print(txt.title())
# Out:
# Hello Everyone Welcome To My Space

# %%
def title(text):
    # initialize an empty list to store the words title case 
    output = []
    # loop through each word in the input text 
    for word in text.split(' '):
        #  Append the word with first letter capitalized and the rest in lowercse 
        output.append(word[0].upper() + word[1:].lower())
  # join the words into a single string and return the result 
    return ' '.join(output)
# Test the function with a sample sentence 
print(title("let us study machine learning today"))
# Out:
# Let Us Study Machine Learning Today

# %%
# its working fine
